# %% [markdown]
# ### price prediction of Housing dataset using  LinearRegression

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df=pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.shape
# Out:
# (545, 13)

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#univariant analysis
plt.hist(df['price'],bins=30,color="red")
plt.show()

# %%
plt.hist(df['area'],bins=30,color="blue")
plt.show()

# %%
#Bivariant analysis
df.plot(x='area', y='price', kind='scatter', color='blue')
plt.title(' HomePrice related to area')
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
s=df.copy()
s
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
f=s.drop(['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus'],axis=1)
f
# Out:
#         price  area  bedrooms  bathrooms  stories  parking
# 0    13300000  7420         4          2        3        2
# 1    12250000  8960         4          4        4        3
# 2    12250000  9960         3          2        2        2
# 3    12215000  7500         4          2        2        3
# 4    11410000  7420         4          1        2        2
# ..        ...   ...       ...        ...      ...      ...
# 540   1820000  3000         2          1        1        2
# 541   1767150  2400         3          1        1        0
# 542   1750000  3620         2          1        1        0
# 543   1750000  2910         3          1        1        0
# 544   1750000  3850         3          1        2        0
#
# [545 rows x 6 columns]

# %%
#Multivariant analysis
import seaborn as sns
corr = f.corr()
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
#Genearte the model
X=df[['area','bedrooms','bathrooms','stories','parking']]
Y=df['price']

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 0    7420         4          2        3        2
# 1    8960         4          4        4        3
# 2    9960         3          2        2        2
# 3    7500         4          2        2        3
# 4    7420         4          1        2        2
# ..    ...       ...        ...      ...      ...
# 540  3000         2          1        1        2
# 541  2400         3          1        1        0
# 542  3620         2          1        1        0
# 543  2910         3          1        1        0
# 544  3850         3          1        2        0
#
# [545 rows x 5 columns]

# %%
Y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
len(x_train)
# Out:
# 436

# %%
len(x_test)
# Out:
# 109

# %%
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# reg.predict(x_test)

# %%
y_test
# Out:
# 482    2940000
# 314    4095000
# 383    3570000
# 487    2870000
# 43     7700000
#         ...
# 98     6293000
# 307    4165000
# 399    3500000
# 214    4865000
# 173    5250000
# Name: price, Length: 109, dtype: int64

# %%
#accuracy of the model
reg.score(x_test,y_test)
# Out:
# 0.641619951255782
